# %% [markdown]
# <a href="https://colab.research.google.com/github/mini-mipu/ckip_demo/blob/main/CKIP_transformers_nlp_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 安裝

# %%
# !pip install -U ckip-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 58.0 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 49.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 79.7 MB/s
# ...

# %%
from ckip_transformers import __version__
print(__version__)
# Out:
# 0.3.2

# %% [markdown]
# # 載入套件

# %%
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker

# %%
# Use CPU: device=-1
# Use GPU: device=0
ws_driver  = CkipWordSegmenter(model="bert-base",device=0)
pos_driver = CkipPosTagger(model="bert-base",device=0)
ner_driver = CkipNerChunker(model="bert-base",device=0)
# Out:
# Downloading:   0%|          | 0.00/804 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/407M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.86k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/407M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.71k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/407M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# Input text
text = ["2022卡達世界盃足球賽16強淘汰賽最終回今天（7日）由葡萄牙對決瑞士"]
# Run pipeline
ws  = ws_driver(text)
pos = pos_driver(ws)

ner = ner_driver(text)
# Out:
# ...
# Inference: 100%|██████████| 1/1 [00:00<00:00, 79.53it/s]

# %%
for i in range(len(ws)):
  print(ws[i])
  print(pos[i])
  print(ner[i])
  print('------------------------------------------')
# Out:
# ['2022', '卡達', '世界盃', '足球賽', '16', '強', '淘汰賽', '最終回', '今天', '（', '7日', '）', '由', '葡萄牙', '對決', '瑞士']
# ['Neu', 'Nc', 'Nb', 'Na', 'Neu', 'Na', 'Na', 'D', 'Nd', 'PARENTHESISCATEGORY', 'Nd', 'PARENTHESISCATEGORY', 'P', 'Nc', 'VA', 'Nc']
# [NerToken(word='2022', ner='CARDINAL', idx=(0, 4)), NerToken(word='卡達', ner='GPE', idx=(4, 6)), NerToken(word='世界盃足球賽', ner='EVENT', idx=(6, 12)), NerToken(word='16', ner='CARDINAL', idx=(12, 14)), NerToken(word='今天', ner='DATE', idx=(21, 23)), NerToken(word='7日', ner='DATE', idx=(24, 26)), NerToken(word='葡萄牙', ner='GPE', idx=(28, 31)), NerToken(word='瑞士', ner='GPE', idx=(33, 35))]
# ------------------------------------------
